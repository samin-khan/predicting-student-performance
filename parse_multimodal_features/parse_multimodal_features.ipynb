# %% [markdown]
# # Write Image Feature Extractor

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import requests

def extract_image_features(image_paths: list[str]):
    line_counts = []
    contour_counts = []

    for path in image_paths:
        response = requests.get(path)
        img_array = np.asarray(bytearray(response.content), dtype=np.uint8)
        img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)
        if img is None:
            print(f"Failed to load image from URL: {path}")
            continue
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        edges = cv2.Canny(gray, threshold1=50, threshold2=150)

        # Count lines
        lines = cv2.HoughLines(edges, 1, np.pi / 180, 100)
        num_lines = len(lines) if lines is not None else 0

        # Count regions (e.g., boxes or labeled areas)
        contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        num_regions = len(contours)

        line_counts.append(num_lines)
        contour_counts.append(num_regions)

    return {
        "avg_lines_per_image": np.mean(line_counts),
        "avg_regions_per_image": np.mean(contour_counts),
        "total_images": len(image_paths),
    }

# %% [markdown]
# # Write Text Feature Extractor

# %%
from wordfreq import zipf_frequency
import re
import numpy as np

def extract_text_features(text: str):
    words = re.findall(r'\b\w+\b', text.lower())
    total_words = len(words)
    
    if total_words == 0:
        return {
            "avg_word_length": 0.0,
            "mean_word_rarity": 0.0,
            "num_complex_words": 0,
            "total_word_count": 0
        }

    # Compute average word length
    avg_word_length = sum(len(word) for word in words) / total_words

    # Zipf scores: 6+ is common, <5 is rare
    zipf_scores = [zipf_frequency(w, 'en') for w in words]
    mean_word_rarity = np.mean([7 - z for z in zipf_scores])  # Inverted so higher = rarer
    num_complex_words = sum(1 for z in zipf_scores if z < 5.0)  # Empirical threshold

    return {
        "avg_word_length": round(avg_word_length, 2),
        "mean_word_rarity": round(mean_word_rarity, 2),
        "num_complex_words": num_complex_words,
        "total_word_count": total_words
    }

# %% [markdown]
# # Extract Features at Chapter Level

# %%
import pandas as pd

df_chapter_quiz_page_content_all = pd.read_csv("data/chapter_quiz_page_content_all.csv", index_col=0)

# %%
# Extract text features for each chapter
for idx, text in enumerate(df_chapter_quiz_page_content_all['text']):
    features = extract_text_features(text)
    for key, value in features.items():
        df_chapter_quiz_page_content_all.loc[idx, "TEXT_FEATURE_" + key] = value

# Display the dataframe with new features
df_chapter_quiz_page_content_all

# Extract image features for each chapter
for idx, image_urls in enumerate(df_chapter_quiz_page_content_all['images']):
    # Extract image features using the extract_image_features function
    if isinstance(image_urls, str) and image_urls != '[]':
        image_list = eval(image_urls)
        features = extract_image_features(image_list)
        for key, value in features.items():
            df_chapter_quiz_page_content_all.loc[idx, "IMAGE_FEATURE_" + key] = value

# Display the dataframe with all features
df_chapter_quiz_page_content_all
# Out:
#     chapter                                               urls  \
# 0         1  ['https://coursekata.org/preview/book/3cc54c0e...
# 1         2  ['https://coursekata.org/preview/book/3cc54c0e...
# 2         3  ['https://coursekata.org/preview/book/3cc54c0e...
# 3         4  ['https://coursekata.org/preview/book/3cc54c0e...
# 4         5  ['https://coursekata.org/preview/book/3cc54c0e...
# 5         6  ['https://coursekata.org/preview/book/3cc54c0e...
# 6         7  ['https://coursekata.org/preview/book/3cc54c0e...
# 7         8  ['https://coursekata.org/preview/book/3cc54c0e...
# 8         9  ['https://coursekata.org/preview/book/3cc54c0e...
# 9        10  ['https://coursekata.org/preview/book/3cc54c0e...
# 10       11  ['https://coursekata.org/preview/book/3cc54c0e...
# 11       12  ['https://coursekata.org/preview/book/3cc54c0e...
# 12        1  ['https://coursekata.org/preview/book/dab6aeef...
# 13        2  ['https://coursekata.org/preview/book/dab6aeef...
# 14        3  ['https://coursekata.org/preview/book/dab6aeef...
# 15        4  ['https://coursekata.org/preview/book/dab6aeef...
# 16        5  ['https://coursekata.org/preview/book/dab6aeef...
# 17        6  ['https://coursekata.org/preview/book/dab6aeef...
# 18        7  ['https://coursekata.org/preview/book/dab6aeef...
# 19        8  ['https://coursekata.org/preview/book/dab6aeef...
# 20        9  ['https://coursekata.org/preview/book/dab6aeef...
# 21       10  ['https://coursekata.org/preview/book/dab6aeef...
# 22       11  ['https://coursekata.org/preview/book/dab6aeef...
# 23       12  ['https://coursekata.org/preview/book/dab6aeef...
#
#                                                  text  \
# 0   \nQuestion ID: A1_Review1_01\n1. What will hap...
# 1   \nChapter Quiz Page 1:\n\nQuestion ID: A2_Revi...
# 2   \nChapter Quiz Page 1:\n\nQuestion ID: A3_Revi...
# 3   \nChapter Quiz Page 1:\n\nQuestion ID: A4_Revi...
# 4   \nChapter Quiz Page 1:\n\nQuestion ID: B1_Revi...
# 5   \nChapter Quiz Page 1:\n\nQuestion ID: B2_Revi...
# 6   \nQuestion ID: B3_Review2_01\nThe following se...
# 7   \nQuestion ID: B3_Review1_01\nStudentSurvey is...
# 8   \nChapter Quiz Page 1:\n\nQuestion ID: B4_Revi...
# 9   \nChapter Quiz Page 1:\n\nQuestion ID: C1_Revi...
# 10  \nChapter Quiz Page 1:\n\nQuestion ID: C2_Revi...
# 11  \nChapter Quiz Page 1:\n\nQuestion ID: C3_Revi...
# 12  \nQuestion ID: A1_Review1_01\n1. What will hap...
# 13  \nChapter Quiz Page 1:\n\nQuestion ID: A2_Revi...
# 14  \nChapter Quiz Page 1:\n\nQuestion ID: A3_Revi...
# 15  \nChapter Quiz Page 1:\n\nQuestion ID: A4_Revi...
# 16  \nChapter Quiz Page 1:\n\nQuestion ID: B1_Revi...
# 17  \nChapter Quiz Page 1:\n\nQuestion ID: B2_Revi...
# 18  \nQuestion ID: B3_Review2_01\nThe following se...
# 19  \nQuestion ID: B3_Review1_01\nStudentSurvey is...
# 20  \nChapter Quiz Page 1:\n\nQuestion ID: B4_Revi...
# 21  \nChapter Quiz Page 1:\n\nQuestion ID: C1_Revi...
# 22  \nChapter Quiz Page 1:\n\nQuestion ID: C2_Revi...
# 23  \nChapter Quiz Page 1:\n\nQuestion ID: C3_Revi...
#
#                                                images  \
# 0                                                  []
# 1                                                  []
# 2   ['https://coursekata-course-assets.s3.us-west-...
# 3   ['https://coursekata-course-assets.s3.us-west-...
# 4   ['https://coursekata-course-assets.s3.us-west-...
# 5   ['https://coursekata-course-assets.s3.us-west-...
# 6                                                  []
# 7   ['https://coursekata-course-assets.s3.us-west-...
# 8   ['https://coursekata-course-assets.s3.us-west-...
# 9   ['https://coursekata-course-assets.s3.us-west-...
# 10  ['https://coursekata-course-assets.s3.us-west-...
# 11  ['https://coursekata-course-assets.s3.us-west-...
# 12                                                 []
# 13                                                 []
# 14  ['https://coursekata-course-assets.s3.us-west-...
# 15  ['https://coursekata-course-assets.s3.us-west-...
# 16  ['https://coursekata-course-assets.s3.us-west-...
# 17  ['https://coursekata-course-assets.s3.us-west-...
# 18                                                 []
# 19  ['https://coursekata-course-assets.s3.us-west-...
# 20  ['https://coursekata-course-assets.s3.us-west-...
# 21  ['https://coursekata-course-assets.s3.us-west-...
# 22                                                 []
# 23  ['https://coursekata-course-assets.s3.us-west-...
#
#                                                  book  \
# 0         College / Statistics and Data Science (ABC)
# 1         College / Statistics and Data Science (ABC)
# 2         College / Statistics and Data Science (ABC)
# 3         College / Statistics and Data Science (ABC)
# 4         College / Statistics and Data Science (ABC)
# 5         College / Statistics and Data Science (ABC)
# 6         College / Statistics and Data Science (ABC)
# 7         College / Statistics and Data Science (ABC)
# 8         College / Statistics and Data Science (ABC)
# 9         College / Statistics and Data Science (ABC)
# 10        College / Statistics and Data Science (ABC)
# 11        College / Statistics and Data Science (ABC)
# 12  College / Advanced Statistics and Data Science...
# 13  College / Advanced Statistics and Data Science...
# 14  College / Advanced Statistics and Data Science...
# 15  College / Advanced Statistics and Data Science...
# 16  College / Advanced Statistics and Data Science...
# 17  College / Advanced Statistics and Data Science...
# 18  College / Advanced Statistics and Data Science...
# 19  College / Advanced Statistics and Data Science...
# 20  College / Advanced Statistics and Data Science...
# 21  College / Advanced Statistics and Data Science...
# 22  College / Advanced Statistics and Data Science...
# 23  College / Advanced Statistics and Data Science...
#
#     TEXT_FEATURE_avg_word_length  TEXT_FEATURE_mean_word_rarity  \
# 0                           4.71                           1.73
# 1                           4.13                           1.96
# 2                           4.83                           1.88
# 3                           4.84                           1.99
# 4                           4.51                           1.94
# 5                           4.56                           1.91
# 6                           4.46                           2.11
# 7                           4.59                           2.18
# 8                           4.77                           2.19
# 9                           4.96                           2.26
# 10                          5.15                           2.06
# 11                          4.84                           2.08
# 12                          4.71                           1.73
# 13                          4.13                           1.96
# 14                          4.83                           1.88
# 15                          4.84                           1.99
# 16                          4.51                           1.94
# 17                          4.56                           1.91
# 18                          4.46                           2.11
# 19                          4.59                           2.18
# 20                          5.39                           2.68
# 21                          7.57                           3.95
# 22                          8.97                           4.88
# 23                          6.15                           2.71
#
#     TEXT_FEATURE_num_complex_words  TEXT_FEATURE_total_word_count  \
# 0                            143.0                          479.0
# 1                            610.0                         1773.0
# 2                            683.0                         1829.0
# 3                            710.0                         1866.0
# 4                            620.0                         1605.0
# 5                            547.0                         1467.0
# 6                            408.0                          923.0
# 7                            564.0                         1301.0
# 8                           1061.0                         2422.0
# 9                            639.0                         1548.0
# 10                           799.0                         1917.0
# 11                           826.0                         2055.0
# 12                           143.0                          479.0
# 13                           610.0                         1773.0
# 14                           683.0                         1829.0
# 15                           710.0                         1866.0
# 16                           620.0                         1605.0
# 17                           547.0                         1467.0
# 18                           408.0                          923.0
# 19                           564.0                         1301.0
# 20                           429.0                          859.0
# 21                           186.0                          283.0
# 22                           144.0                          183.0
# 23                           421.0                          805.0
#
#     IMAGE_FEATURE_avg_lines_per_image  IMAGE_FEATURE_avg_regions_per_image  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                          184.500000                            32.500000
# 3                         1575.230769                            57.538462
# 4                          192.666667                            44.666667
# 5                          365.222222                            56.777778
# 6                                 NaN                                  NaN
# 7                         1741.500000                            57.000000
# 8                         2227.857143                            83.571429
# 9                         5346.500000                           112.750000
# 10                         158.000000                            55.000000
# 11                         192.333333                            57.333333
# 12                                NaN                                  NaN
# 13                                NaN                                  NaN
# 14                         184.500000                            32.500000
# 15                        1575.230769                            57.538462
# 16                         192.666667                            44.666667
# 17                         365.222222                            56.777778
# 18                                NaN                                  NaN
# 19                        1741.500000                            57.000000
# 20                        5219.500000                           171.000000
# 21                         262.000000                            69.000000
# 22                                NaN                                  NaN
# 23                         191.666667                            56.000000
#
#     IMAGE_FEATURE_total_images
# 0                          NaN
# 1                          NaN
# 2                          2.0
# 3                         13.0
# 4                          3.0
# 5                          9.0
# 6                          NaN
# 7                          2.0
# 8                          7.0
# 9                          4.0
# 10                         6.0
# 11                         6.0
# 12                         NaN
# 13                         NaN
# 14                         2.0
# 15                        13.0
# 16                         3.0
# 17                         9.0
# 18                         NaN
# 19                         2.0
# 20                         2.0
# 21                         1.0
# 22                         NaN
# 23                         3.0

# %%
df_chapter_quiz_page_content_all.to_csv("data/chapter_quiz_with_multimodal_features.csv")
